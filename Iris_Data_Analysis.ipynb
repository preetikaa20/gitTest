# %% [markdown]
# <a href="https://colab.research.google.com/github/preetikaa20/gitTest/blob/iris-project/Iris_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load a dataset (Iris dataset from GitHub)
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)

# Display first 5 rows of the dataset
print("Dataset Sample:\n", df.head())

# Check for missing values
print("\nMissing Values:\n", df.isnull().sum())

# Count the number of each species in the dataset
species_count = df["species"].value_counts()

# Plot a bar chart for species count
plt.figure(figsize=(6,4))
species_count.plot(kind="bar", color=['blue', 'green', 'red'])
plt.xlabel("Species")
plt.ylabel("Count")
plt.title("Distribution of Iris Species")
plt.show()
# Out:
# Dataset Sample:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Missing Values:
#  sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
